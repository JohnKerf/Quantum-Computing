# %%
import json
from pathlib import Path

# %%
import json
from pathlib import Path


def load_json(path):
    with open(path, "r") as f:
        return json.load(f)


def get_pauli_labels_from_l8_fock(data):
    """
    Try multiple possibilities for L8_Fock.json:
    1) Direct pauli_labels list
    2) Reconstruct from ablation variants via removed_label
    """
    if "pauli_labels" in data and isinstance(data["pauli_labels"], list):
        return data["pauli_labels"]

    variants = data.get("variants", [])
    if isinstance(variants, list) and variants:
        labels = []
        for v in variants:
            lbl = v.get("removed_label")
            if isinstance(lbl, str):
                labels.append(lbl)

        # Deduplicate while preserving order
        seen = set()
        deduped = []
        for lbl in labels:
            if lbl not in seen:
                seen.add(lbl)
                deduped.append(lbl)

        if deduped:
            return deduped

    raise ValueError(
        "Could not find Pauli labels in L8_Fock.json "
        "(neither 'pauli_labels' nor variants[*]['removed_label'])."
    )


def compare_paulis_with_ground_metrics(
    linear8_path,
    l8_fock_path,
    save_output=True,
    output_name="pauli_comparison_linear8_vs_L8_Fock_with_ground_metrics.json",
):
    linear8 = load_json(linear8_path)
    l8_fock = load_json(l8_fock_path)

    # --- Required from linear_8 ---
    linear_labels = linear8.get("pauli_labels")
    if not isinstance(linear_labels, list):
        raise ValueError("linear_8.json must contain a 'pauli_labels' list.")

    # Optional aligned arrays from linear_8
    expvals_ground = linear8.get("pauli_expvals_ground", None)
    energy_contrib_ground = linear8.get("pauli_energy_contrib_ground", None)

    n = len(linear_labels)

    if expvals_ground is not None and len(expvals_ground) != n:
        raise ValueError(
            f"'pauli_expvals_ground' length ({len(expvals_ground)}) "
            f"does not match 'pauli_labels' length ({n})."
        )

    if energy_contrib_ground is not None and len(energy_contrib_ground) != n:
        raise ValueError(
            f"'pauli_energy_contrib_ground' length ({len(energy_contrib_ground)}) "
            f"does not match 'pauli_labels' length ({n})."
        )

    # --- Labels from L8_Fock ---
    l8_labels = get_pauli_labels_from_l8_fock(l8_fock)
    l8_set = set(l8_labels)

    # --- Build rows ---
    only_in_linear8 = []
    in_both = []

    for i, label in enumerate(linear_labels):
        row = {
            "index_in_linear_8": i,
            "pauli_label": label,
            "pauli_expvals_ground": expvals_ground[i] if expvals_ground is not None else None,
            "pauli_energy_contrib_ground": (
                energy_contrib_ground[i] if energy_contrib_ground is not None else None
            ),
        }

        if label in l8_set:
            in_both.append(row)
        else:
            only_in_linear8.append(row)

    # --- Print summary ---
    print(f"linear_8 labels: {len(linear_labels)}")
    print(f"L8_Fock labels:  {len(l8_labels)}")
    print(f"In both: {len(in_both)}")
    print(f"Only in linear_8: {len(only_in_linear8)}")

    # --- Print in both ---
    print("\n" + "=" * 80)
    print("PAULIS IN BOTH (with ground metrics)")
    print("=" * 80)
    for row in in_both:
        print(
            f"{row['pauli_label']:<20} "
            f"expval={row['pauli_expvals_ground']} "
            f"energy_contrib={row['pauli_energy_contrib_ground']}"
        )

    # --- Print only in linear_8 ---
    print("\n" + "=" * 80)
    print("PAULIS IN linear_8 BUT NOT IN L8_Fock (with ground metrics)")
    print("=" * 80)
    for row in only_in_linear8:
        print(
            f"{row['pauli_label']:<20} "
            f"expval={row['pauli_expvals_ground']} "
            f"energy_contrib={row['pauli_energy_contrib_ground']}"
        )

    # --- Save ---
    if save_output:
        out_path = Path(linear8_path).with_name(output_name)
        out_obj = {
            "linear8_path": str(linear8_path),
            "l8_fock_path": str(l8_fock_path),
            "counts": {
                "linear8_total": len(linear_labels),
                "l8_fock_total_labels": len(l8_labels),
                "in_both": len(in_both),
                "only_in_linear8": len(only_in_linear8),
            },
            "in_both": in_both,
            "only_in_linear8": only_in_linear8,
        }
        with open(out_path, "w") as f:
            json.dump(out_obj, f, indent=2)
        print(f"\nSaved results to: {out_path}")

    return in_both, only_in_linear8

# %%
linear8_path = r"C:\Users\Johnk\Documents\PhD\Quantum Computing Code\Quantum-Computing\SUSY\Wess-Zumino\Analyses\Model Checks\GroundstatePauliContributions\dirichlet\linear\N3\linear_8.json"
l8_fock_path = r"C:\Users\Johnk\Documents\PhD\Quantum Computing Code\Quantum-Computing\SUSY\Wess-Zumino\Qiskit\SKQD\ML-Testing\ML-Testing2\linear\N3\L8_Fock.json"

in_both, only_in_linear8 = compare_paulis_with_ground_metrics(
        linear8_path,
        l8_fock_path,
        save_output=False,
        )
# Out:
# linear_8 labels: 194
# L8_Fock labels:  57
# In both: 57
# Only in linear_8: 137
#
# ================================================================================
# PAULIS IN BOTH (with ground metrics)
# ================================================================================
# IIIIIIIIIIII         expval=1.000000000000001 energy_contrib=12.250000000000014
# IIIIIIIIIIZI         expval=0.9974128208554678 energy_contrib=-0.5610447117312006
# IIIIIIIIIIZZ         expval=0.9923364331620248 energy_contrib=-0.558189243653639
# IIIIIIIIIZII         expval=0.9999949109653523 energy_contrib=-1.6874914122540319
# IIIIIIIIIZIZ         expval=0.9948793795737214 energy_contrib=-0.5596196510102183
# IIIIIIIIIZZI         expval=0.9974077553968611 energy_contrib=-0.5610418624107343
# IIIIIIIIIZZZ         expval=0.9923314934782442 energy_contrib=0.558186465081512
# IIIIIIIIZIII         expval=0.9082482904638636 energy_contrib=-0.4541241452319318
# IIIIIIZIIIII         expval=0.9898464624210701 energy_contrib=-0.6186540390131688
# IIIIIIZZIIII         expval=0.9898464624210701 energy_contrib=-0.6186540390131688
# IIIIIZIIIIII         expval=0.9999216693170163 energy_contrib=-1.8748531299694053
# IIIIIZIZIIII         expval=0.9999216693170163 energy_contrib=-0.6249510433231352
# IIIIIZZIIIII         expval=0.9897694221471517 energy_contrib=-0.6186058888419697
# IIIIIZZZIIII         expval=0.9897694221471517 energy_contrib=0.6186058888419694
# IIIIZIIIIIII         expval=-0.816496580927726 energy_contrib=-0.408248290463863
# IIZIIIIIIIII         expval=0.9974128208554673 energy_contrib=-0.5610447117312004
# IIZZIIIIIIII         expval=0.9923364331620246 energy_contrib=-0.5581892436536389
# IZIIIIIIIIII         expval=0.9999949109653519 energy_contrib=-1.687491412254031
# IZIZIIIIIIII         expval=0.994879379573721 energy_contrib=-0.559619651010218
# IZZIIIIIIIII         expval=0.9974077553968614 energy_contrib=-0.5610418624107345
# IZZZIIIIIIII         expval=0.9923314934782452 energy_contrib=0.5581864650815126
# ZIIIIIIIIIII         expval=0.9082482904638636 energy_contrib=-0.4541241452319318
# IIIIXIIIXIII         expval=-0.40824829046386374 energy_contrib=-0.10206207261596593
# IIIIYIIIYIII         expval=-0.40824829046386374 energy_contrib=-0.10206207261596593
# XIIIXIIIIIII         expval=-0.40824829046386374 energy_contrib=-0.10206207261596593
# YIIIYIIIIIII         expval=-0.40824829046386374 energy_contrib=-0.10206207261596593
# IIIIIIXIIIII         expval=-0.14214049681123572 energy_contrib=-0.07027812419648946
# IIIIIXXIIIII         expval=-0.0020211584608727244 energy_contrib=-0.0005012623035118457
# IIIIIYYIIIII         expval=0.000244946421993142 energy_contrib=6.074853115289647e-05
# IIIIIZXIIIII         expval=-0.14212633728824017 energy_contrib=0.03595024839789934
# IIXIIIIIIIII         expval=-0.07165601684042877 energy_contrib=-0.01771434096514051
# IXXIIIIIIIII         expval=-0.00026129568498375915 energy_contrib=-3.240163487629498e-05
# IYYIIIIIIIII         expval=3.2713573915394175e-05 energy_contrib=4.0566045993877485e-06
# IZXIIIIIIIII         expval=-0.07165553378283893 energy_contrib=0.0090624802120693
# IIIIIIIIIIXI         expval=-0.0716560168404288 energy_contrib=-0.017714340965140518
# IIIIIIIIIXXI         expval=-0.000261295684983739 energy_contrib=-3.240163487629248e-05
# IIIIIIIIIYYI         expval=3.271357391536986e-05 energy_contrib=4.056604599384734e-06
# IIIIIIIIIZXI         expval=-0.07165553378283904 energy_contrib=0.009062480212069315
# IIIXIIIIIIIX         expval=0.10095144616767679 energy_contrib=-0.045720766303438826
# IIIXIIIIIIXX         expval=-0.009854002346270442 energy_contrib=0.0022647064863943024
# IIIXIIIIIIYY         expval=0.0026269512439191707 energy_contrib=-0.0006037418413845839
# IIIXIIIIIXXX         expval=-6.902551807645245e-05 energy_contrib=8.211739499256357e-06
# IIIXIIIIIXYY         expval=2.8729370109368777e-05 energy_contrib=3.4178389368198054e-06
# IIIXIIIIIYXY         expval=3.449299508450368e-05 energy_contrib=-4.103518496874594e-06
# IIIXIIIIIYYX         expval=2.3684576460639693e-05 energy_contrib=-2.817676382081972e-06
# IIIXIIIIIZIX         expval=0.10095031104368514 energy_contrib=0.01290906672922437
# IIXXIIIIIIIX         expval=-0.009854002346270433 energy_contrib=0.0022647064863943003
# IIXXIIIIIIXX         expval=0.0014698691182243662 energy_contrib=-0.00017142581967780619
# IIXXIIIIIIYY         expval=-0.00025644957787504145 energy_contrib=2.9908839194038935e-05
# IIYYIIIIIIIX         expval=0.002626951243919165 energy_contrib=-0.0006037418413845826
# IIYYIIIIIIXX         expval=-0.00025644957787504085 energy_contrib=2.9908839194038864e-05
# IIYYIIIIIIYY         expval=0.0005815592846154023 energy_contrib=-6.782527493119032e-05
# IXXXIIIIIIIX         expval=-6.902551807637425e-05 energy_contrib=8.211739499247053e-06
# IXYYIIIIIIIX         expval=2.8729370109289586e-05 energy_contrib=3.4178389368103843e-06
# IYXYIIIIIIIX         expval=3.449299508442316e-05 energy_contrib=-4.1035184968650145e-06
# IYYXIIIIIIIX         expval=2.3684576460563507e-05 energy_contrib=-2.817676382072908e-06
# IZIXIIIIIIIX         expval=0.10095031104368515 energy_contrib=0.012909066729224376
#
# ================================================================================
# PAULIS IN linear_8 BUT NOT IN L8_Fock (with ground metrics)
# ================================================================================
# IIIIIIXZIIII         expval=-0.14214049681123572 energy_contrib=0.009056087775367695
# IIIIIXXZIIII         expval=-0.0020211584608727244 energy_contrib=6.366866046443683e-05
# IIIIIYYZIIII         expval=0.000244946421993142 energy_contrib=-7.716075149855401e-06
# IIIIIZXZIIII         expval=-0.14212633728824017 energy_contrib=0.00014106508460847887
# IIXZIIIIIIII         expval=-0.07102388943498628 energy_contrib=0.0022625451271829355
# IXXZIIIIIIII         expval=-0.0002551061124448511 energy_contrib=4.018058150829093e-06
# IYYZIIIIIIII         expval=3.0992453714078885e-05 energy_contrib=-4.88147775318276e-07
# IZXZIIIIIIII         expval=-0.07102343448565171 energy_contrib=3.524655241971187e-05
# IIIIIIIIIIXZ         expval=-0.07102388943498625 energy_contrib=0.0022625451271829347
# IIIIIIIIIXXZ         expval=-0.0002551061124448229 energy_contrib=4.018058150828648e-06
# IIIIIIIIIYYZ         expval=3.0992453714046725e-05 energy_contrib=-4.881477753177695e-07
# IIIIIIIIIZXZ         expval=-0.07102343448565171 energy_contrib=3.524655241971187e-05
# IIIXIIIIIIZX         expval=0.10050237919957995 energy_contrib=0.006825536981463577
# IIIXIIIIIZXX         expval=-0.00985382489323187 energy_contrib=-0.0006068153462620516
# IIIXIIIIIZYY         expval=0.0026268792112694194 energy_contrib=0.00016176770294242825
# IIIXIIIIIZZX         expval=0.10050125573709895 energy_contrib=0.001927161884572647
# IIXXIIIIIIZX         expval=-0.009760614837975707 energy_contrib=-0.00033638449001111487
# IIXXIIIIIXXX         expval=1.5971777800656706e-05 energy_contrib=-9.642220418377952e-07
# IIXXIIIIIXYY         expval=-5.213875366798378e-06 energy_contrib=-3.147635544901838e-07
# IIXXIIIIIYXY         expval=-6.0716767040462e-06 energy_contrib=3.6654933358224444e-07
# IIXXIIIIIYYX         expval=-4.168892673054082e-06 energy_contrib=2.5167756874563787e-07
# IIXXIIIIIZIX         expval=-0.009853644511455519 energy_contrib=-0.0006394143537038646
# IIXXIIIIIZXX         expval=0.001469807538522952 energy_contrib=4.593148557884223e-05
# IIXXIIIIIZYY         expval=-0.00025642744619756814 energy_contrib=-8.013357693674001e-06
# IIXXIIIIIZZX         expval=-0.009760261596934914 energy_contrib=-9.497438147907373e-05
# IIYYIIIIIIZX         expval=0.002628744634348072 energy_contrib=9.059561696402549e-05
# IIYYIIIIIXXX         expval=-3.5096880173864894e-06 energy_contrib=2.1188114363818036e-07
# IIYYIIIIIXYY         expval=5.201629787414922e-06 energy_contrib=3.1402428440366173e-07
# IIYYIIIIIYXY         expval=7.605373311673617e-06 energy_contrib=-4.591391562696978e-07
# IIYYIIIIIYYX         expval=4.03686785810155e-06 energy_contrib=-2.4370718259103254e-07
# IIYYIIIIIZIX         expval=0.0026269891938998187 energy_contrib=0.0001704683577382648
# IIYYIIIIIZXX         expval=-0.0002564559819449565 energy_contrib=-8.014249435779887e-06
# IIYYIIIIIZYY         expval=0.0005815556609115798 energy_contrib=1.817361440348686e-05
# IIYYIIIIIZZX         expval=0.0026287817345181166 energy_contrib=2.5579941357078937e-05
# IIZXIIIIIIIX         expval=0.1005023791995798 energy_contrib=0.006825536981463564
# IIZXIIIIIIXX         expval=-0.009760614837975723 energy_contrib=-0.00033638449001111557
# IIZXIIIIIIYY         expval=0.002628744634348082 energy_contrib=9.059561696402587e-05
# IIZXIIIIIIZX         expval=0.10006312631251167 energy_contrib=-0.001019046669062925
# IIZXIIIIIXXX         expval=-6.759778003927776e-05 energy_contrib=-1.2059170833701267e-06
# IIZXIIIIIXYY         expval=2.8517042871470833e-05 energy_contrib=-5.087325226645476e-07
# IIZXIIIIIYXY         expval=3.4217253988480924e-05 energy_contrib=6.104219858514251e-07
# IIZXIIIIIYYX         expval=2.3750988658425805e-05 energy_contrib=4.237080412031801e-07
# IIZXIIIIIZIX         expval=0.10050130130086628 energy_contrib=-0.0019271627582806952
# IIZXIIIIIZXX         expval=-0.00976044818108326 energy_contrib=9.013241345936276e-05
# IIZXIIIIIZYY         expval=0.002628676251969697 energy_contrib=-2.4274390929356413e-05
# IIZXIIIIIZZX         expval=0.10006205916607377 energy_contrib=-0.0002877237224660734
# IXXXIIIIIIXX         expval=1.597177780067599e-05 energy_contrib=-9.642220418389595e-07
# IXXXIIIIIIYY         expval=-3.5096880174116285e-06 energy_contrib=2.1188114363969803e-07
# IXXXIIIIIIZX         expval=-6.759778003919805e-05 energy_contrib=-1.2059170833687048e-06
# IXXXIIIIIXXX         expval=3.5916524793470813e-07 energy_contrib=-1.1223913997959626e-08
# IXXXIIIIIXYY         expval=-1.3315919782946676e-07 energy_contrib=-4.1612249321708355e-09
# IXXXIIIIIYXY         expval=-1.5559223783804185e-07 energy_contrib=4.862257432438807e-09
# IXXXIIIIIYYX         expval=-1.099711441302618e-07 energy_contrib=3.4365982540706805e-09
# IXXXIIIIIZIX         expval=-6.901560600980809e-05 energy_contrib=-2.3182433515107692e-06
# IXXXIIIIIZXX         expval=1.596965634948706e-05 energy_contrib=2.583282004368529e-07
# IXXXIIIIIZYY         expval=-3.5089262554252394e-06 energy_contrib=-5.676105892277024e-08
# IXXXIIIIIZZX         expval=-6.758805810832795e-05 energy_contrib=-3.4044049320660016e-07
# IXYYIIIIIIXX         expval=-5.213875366818296e-06 energy_contrib=-3.147635544913863e-07
# IXYYIIIIIIYY         expval=5.201629787440603e-06 energy_contrib=3.140242844052121e-07
# IXYYIIIIIIZX         expval=2.851704287138999e-05 energy_contrib=-5.087325226631053e-07
# IXYYIIIIIXXX         expval=-1.3315919782974332e-07 energy_contrib=-4.161224932179478e-09
# IXYYIIIIIXYY         expval=1.241232060060881e-07 energy_contrib=-3.878850187690252e-09
# IXYYIIIIIYXY         expval=1.5553491148971018e-07 energy_contrib=4.860465984053442e-09
# IXYYIIIIIYYX         expval=1.016612913414182e-07 energy_contrib=3.176915354419318e-09
# IXYYIIIIIZIX         expval=2.8728555296870328e-05 energy_contrib=-9.64995979402316e-07
# IXYYIIIIIZXX         expval=-5.213642835143899e-06 energy_contrib=8.43368787560964e-08
# IXYYIIIIIZYY         expval=5.201410465750655e-06 energy_contrib=-8.41390056207401e-08
# IXYYIIIIIZZX         expval=2.851624179841155e-05 energy_contrib=-1.4363607557255296e-07
# IYXYIIIIIIXX         expval=-6.07167670406537e-06 energy_contrib=3.6654933358340175e-07
# IYXYIIIIIIYY         expval=7.605373311698601e-06 energy_contrib=-4.5913915627120606e-07
# IYXYIIIIIIZX         expval=3.421725398839891e-05 energy_contrib=6.10421985849962e-07
# IYXYIIIIIXXX         expval=-1.5559223783809396e-07 energy_contrib=4.8622574324404356e-09
# IYXYIIIIIXYY         expval=1.5553491148942955e-07 energy_contrib=4.860465984044673e-09
# IYXYIIIIIYXY         expval=2.260198673755915e-07 energy_contrib=-7.063120855487233e-09
# IYXYIIIIIYYX         expval=1.1744399589172559e-07 energy_contrib=-3.670124871616424e-09
# IYXYIIIIIZIX         expval=3.4492171694955746e-05 energy_contrib=1.1585966179828296e-06
# IYXYIIIIIZXX         expval=-6.0714154857375516e-06 energy_contrib=-9.82123724024531e-08
# IYXYIIIIIZYY         expval=7.604930050721495e-06 energy_contrib=1.2301879586245008e-07
# IYXYIIIIIZZX         expval=3.421643518468103e-05 energy_contrib=1.7234790281109097e-07
# IYYXIIIIIIXX         expval=-4.168892673074468e-06 energy_contrib=2.5167756874686856e-07
# IYYXIIIIIIYY         expval=4.036867858127165e-06 energy_contrib=-2.437071825925789e-07
# IYYXIIIIIIZX         expval=2.3750988658347966e-05 energy_contrib=4.237080412017915e-07
# IYYXIIIIIXXX         expval=-1.0997114413068628e-07 energy_contrib=3.4365982540839455e-09
# IYYXIIIIIXYY         expval=1.0166129134150489e-07 energy_contrib=3.176915354422027e-09
# IYYXIIIIIYXY         expval=1.1744399589201762e-07 energy_contrib=-3.67012487162555e-09
# IYYXIIIIIYYX         expval=1.2690478014475473e-07 energy_contrib=-3.965774379523585e-09
# IYYXIIIIIZIX         expval=2.368637268222965e-05 energy_contrib=7.956283972089096e-07
# IYYXIIIIIZXX         expval=-4.169199224546656e-06 energy_contrib=-6.744176013370843e-08
# IYYXIIIIIZYY         expval=4.036877782139114e-06 energy_contrib=6.530130329805167e-08
# IYYXIIIIIZZX         expval=2.3752748600180345e-05 energy_contrib=1.196423994827187e-07
# IZIXIIIIIIXX         expval=-0.00985364451145553 energy_contrib=-0.0006394143537038654
# IZIXIIIIIIYY         expval=0.0026269891938998286 energy_contrib=0.00017046835773826545
# IZIXIIIIIIZX         expval=0.10050130130086625 energy_contrib=-0.0019271627582806948
# IZIXIIIIIXXX         expval=-6.901560600988635e-05 energy_contrib=-2.318243351513398e-06
# IZIXIIIIIXYY         expval=2.8728555296949546e-05 energy_contrib=-9.64995979404977e-07
# IZIXIIIIIYXY         expval=3.4492171695036316e-05 energy_contrib=1.1585966179855359e-06
# IZIXIIIIIYYX         expval=2.3686372682305802e-05 energy_contrib=7.956283972114675e-07
# IZIXIIIIIZIX         expval=0.10094917652602982 energy_contrib=-0.0036448209046506396
# IZIXIIIIIZXX         expval=-0.009853467195829859 energy_contrib=0.0001713274766226954
# IZIXIIIIIZYY         expval=0.0026269172026482436 energy_contrib=-4.567560704083402e-05
# IZIXIIIIIZZX         expval=0.1005001784303848 energy_contrib=-0.0005441263661224759
# IZXXIIIIIIIX         expval=-0.009853824893231874 energy_contrib=-0.0006068153462620518
# IZXXIIIIIIXX         expval=0.0014698075385229522 energy_contrib=4.593148557884222e-05
# IZXXIIIIIIYY         expval=-0.0002564559819449571 energy_contrib=-8.014249435779904e-06
# IZXXIIIIIIZX         expval=-0.009760448181083254 energy_contrib=9.013241345936275e-05
# IZXXIIIIIXXX         expval=1.596965634946778e-05 energy_contrib=2.5832820043654103e-07
# IZXXIIIIIXYY         expval=-5.213642835123978e-06 energy_contrib=8.433687875577414e-08
# IZXXIIIIIYXY         expval=-6.071415485718388e-06 energy_contrib=-9.821237240214311e-08
# IZXXIIIIIYYX         expval=-4.1691992245262704e-06 energy_contrib=-6.744176013337867e-08
# IZXXIIIIIZIX         expval=-0.009853467195829854 energy_contrib=0.00017132747662269534
# IZXXIIIIIZXX         expval=0.0014697459943999185 energy_contrib=-1.230678913369797e-05
# IZXXIIIIIZYY         expval=-0.0002564338626731035 energy_contrib=2.1472264504766068e-06
# IZXXIIIIIZZX         expval=-0.009760095073392348 energy_contrib=2.5447874635668516e-05
# IZYYIIIIIIIX         expval=0.002626879211269411 energy_contrib=0.0001617677029424277
# IZYYIIIIIIXX         expval=-0.0002564274461975669 energy_contrib=-8.01335769367396e-06
# IZYYIIIIIIYY         expval=0.0005815556609115798 energy_contrib=1.8173614403486855e-05
# IZYYIIIIIIZX         expval=0.002628676251969689 energy_contrib=-2.4274390929356346e-05
# IZYYIIIIIXXX         expval=-3.5089262554000935e-06 energy_contrib=-5.676105892236348e-08
# IZYYIIIIIXYY         expval=5.2014104657249755e-06 energy_contrib=-8.41390056203247e-08
# IZYYIIIIIYXY         expval=7.604930050696503e-06 energy_contrib=1.2301879586204578e-07
# IZYYIIIIIYYX         expval=4.036877782113504e-06 energy_contrib=6.53013032976374e-08
# IZYYIIIIIZIX         expval=0.002626917202648236 energy_contrib=-4.5675607040833906e-05
# IZYYIIIIIZXX         expval=-0.0002564338626731031 energy_contrib=2.1472264504766034e-06
# IZYYIIIIIZYY         expval=0.0005815520446334276 energy_contrib=-4.869575022381093e-06
# IZYYIIIIIZZX         expval=0.0026287133921801906 energy_contrib=-6.853946437435004e-06
# IZZXIIIIIIIX         expval=0.10050125573709892 energy_contrib=0.001927161884572648
# IZZXIIIIIIXX         expval=-0.009760261596934923 energy_contrib=-9.497438147907381e-05
# IZZXIIIIIIYY         expval=0.002628781734518131 energy_contrib=2.5579941357079076e-05
# IZZXIIIIIIZX         expval=0.1000620591660737 energy_contrib=-0.0002877237224660732
# IZZXIIIIIXXX         expval=-6.758805810840768e-05 energy_contrib=-3.4044049320700176e-07
# IZZXIIIIIXYY         expval=2.8516241798492408e-05 energy_contrib=-1.4363607557296023e-07
# IZZXIIIIIYXY         expval=3.421643518476309e-05 energy_contrib=1.7234790281150433e-07
# IZZXIIIIIYYX         expval=2.375274860025819e-05 energy_contrib=1.196423994831108e-07
# IZZXIIIIIZIX         expval=0.10050017843038496 energy_contrib=-0.0005441263661224757
# IZZXIIIIIZXX         expval=-0.00976009507339236 energy_contrib=2.5447874635668546e-05
# IZZXIIIIIZYY         expval=0.0026287133921801997 energy_contrib=-6.853946437435028e-06
# IZZXIIIIIZZX         expval=0.10006099259781942 energy_contrib=-8.123763459705054e-05

# %%
import numpy as np
import pandas as pd
import json
import os
#from tabulate import tabulate

import matplotlib.pyplot as plt

# %%
import git
repo = git.Repo('.', search_parent_directories=True)
repo_path = repo.working_tree_dir

# %%
path1 = os.path.join(repo_path,r"SUSY\SUSY QM\PennyLane\COBYQA\PauliDecomp\VQE\FilesOldBounds\10000")
path2 = os.path.join(repo_path,r"SUSY\SUSY QM\PennyLane\COBYQA\PauliDecomp\VQE\FilesReducedAnsatz\10000")
dataframes = {}
potentials = [f for f in os.listdir(path1) if os.path.isdir(os.path.join(path1, f))]
potentials
# Out:
# ['AHO', 'DW', 'QHO']

# %%
all_data = []
cutoff_list = [2,4,8,16]

for path in [path1,path2]:

    converged_runs = []
    mean_iters = []
    mean_evals = []
    min_e = []
    delta_min_e = []
    median_e = []
    delta_median_e = []
    mean_e = []
    delta_mean_e = []
    exact_e = []
    time_taken = []

    num_vqe = []
    shots_list = []
    maxiter = []
    cutoffs = []
    ps = []

    for potential in potentials:
        for cutoff in cutoff_list:

            d_path = os.path.join(path, potential, f'{potential}_{cutoff}.json')
        
            try:
                with open(d_path, 'r') as json_file:
                    data = json.load(json_file)
            

                converged_indices = [i for i, success in enumerate(data['success']) if success]

                ps.append(potential)
                cutoffs.append(cutoff)

                num_vqe.append(data['num_VQE'])
                shots_list.append(data['shots'])

                optimzer = data['Optimizer']
                maxiter.append(optimzer['maxiter'])
                
                exact_min_e = np.min(data['exact_eigenvalues'])
                exact_e.append(exact_min_e)

                converged_runs.append(sum(data['success']))

                #iters = [data['num_iters'][i] for i in converged_indices]
                #mean_iters.append(int(np.round(np.mean(iters))))
                mean_iters.append(int(np.round(np.mean(data['num_iters']))))

                #evals = [data['num_evaluations'][i] for i in converged_indices]
                #mean_evals.append(int(np.round(np.mean(evals))))
                #mean_evals.append(int(np.round(np.mean(data['num_evaluations']))))

                #results = [data['results'][i] for i in converged_indices]
                results = data['results']
                min_e.append(np.min(results))
                delta_min_e.append(abs(exact_min_e - np.min(results)))
                median_e.append(np.median(results))
                delta_median_e.append(abs(exact_min_e - np.median(results)))
                mean_e.append(np.mean(results))
                delta_mean_e.append(abs(exact_min_e - np.mean(results)))

                #run_times = [data['run_times'][i] for i in converged_indices]
                #time_series = np.array([pd.Timedelta(t).total_seconds() for t in run_times])
                time_series = np.array([pd.Timedelta(t).total_seconds() for t in data['run_times']])
                mean_vqe_time = np.mean(time_series)
                #mean_vqe_time = pd.Timedelta(seconds=np.mean(time_series))
                time_taken.append(np.mean(mean_vqe_time))
                #time_taken.append(data['parallel_run_time'])

            except Exception as e:
                print(e)
                print("Unable to open file...")

    df = {
    'potential': ps,
    'cutoff': cutoffs,
    'Converged Runs': [f"{c}/100" for c in converged_runs],
    #'Mean Iter': mean_iters,
    #'Mean evals': mean_evals,
    'Mean VQE time (s)': [f"{t:.2f}" for t in time_taken],
    #'E_VQE': [f"{num:.5e}" for num in median_e],
    #'Exact': [f"{num:.5e}" for num in exact_e],
    #'Delta': [f"{num:.5e}" for num in delta_median_e],
    #'VQE min E': [f"{num:.5e}" for num in min_e],
    'Delta min E': [f"{num:.5e}" for num in delta_min_e],
    #'VQE median E': [f"{num:.5e}" for num in median_e],
    'Delta median E': [f"{num:.5e}" for num in delta_median_e],
    #'VQE mean E': [f"{num:.5e}" for num in mean_e],
    'Delta mean E': [f"{num:.5e}" for num in delta_mean_e]
    
    }

    all_data.append(df.copy())

# %%
merged = pd.DataFrame(all_data[0]).merge(pd.DataFrame(all_data[1]).reset_index(), on=['potential', 'cutoff'], suffixes=('_path1', '_path2')).drop(columns=['index'])
merged
# Out:
#    potential  cutoff Converged Runs_path1 Mean VQE time (s)_path1  \
# 0        AHO       2              100/100                    0.20
# 1        AHO       4              100/100                    0.37
# 2        AHO       8              100/100                    2.58
# 3        AHO      16              100/100                   11.87
# 4         DW       2              100/100                    0.24
# 5         DW       4              100/100                    1.90
# 6         DW       8              100/100                   13.58
# 7         DW      16              100/100                   49.76
# 8        QHO       2              100/100                    0.15
# 9        QHO       4              100/100                    0.15
# 10       QHO       8              100/100                    0.20
# 11       QHO      16              100/100                    0.32
#
#    Delta min E_path1 Delta median E_path1 Delta mean E_path1  \
# 0        1.11022e-16          1.11022e-16        1.66533e-16
# 1        1.82666e-01          4.90871e-02        4.55319e-01
# 2        3.28509e+00          1.66817e-01        4.30246e-02
# 3        3.77946e+01          2.69269e+00        1.55106e-02
# 4        0.00000e+00          0.00000e+00        4.58891e-01
# 5        6.01650e-02          1.45912e-01        3.55271e-01
# 6        4.52211e-01          1.17044e-01        6.76229e-01
# 7        2.19859e+00          6.17636e-02        6.83415e-01
# 8        0.00000e+00          0.00000e+00        0.00000e+00
# 9        1.11022e-16          1.11022e-16        1.11022e-16
# 10       0.00000e+00          0.00000e+00        0.00000e+00
# 11       4.44089e-16          4.44089e-16        4.44089e-16
#
#    Converged Runs_path2 Mean VQE time (s)_path2 Delta min E_path2  \
# 0               100/100                    0.16       1.11022e-16
# 1               100/100                    0.38       9.78933e-02
# 2               100/100                    3.52       3.01082e+00
# 3               100/100                   12.02       3.78409e+01
# 4               100/100                    0.18       0.00000e+00
# 5               100/100                    2.48       6.05018e-02
# 6               100/100                    8.29       4.97194e-01
# 7               100/100                   32.85       2.65345e+00
# 8               100/100                    0.14       0.00000e+00
# 9               100/100                    0.14       1.11022e-16
# 10              100/100                    0.19       0.00000e+00
# 11              100/100                    0.29       4.44089e-16
#
#    Delta median E_path2 Delta mean E_path2
# 0           1.11022e-16        1.66533e-16
# 1           5.40104e-02        4.96775e-01
# 2           8.38033e-01        1.11792e+00
# 3           1.18003e+00        2.17414e+00
# 4           0.00000e+00        4.05543e-01
# 5           8.30944e-02        2.28904e-01
# 6           5.16507e-01        8.97551e-01
# 7           1.65124e-01        4.90349e-01
# 8           0.00000e+00        0.00000e+00
# 9           1.11022e-16        1.11022e-16
# 10          0.00000e+00        0.00000e+00
# 11          4.44089e-16        4.44089e-16

# %%
exclude = ['potential', 'cutoff', 'Converged Runs_path1','Converged Runs_path2']
cols_to_float = [c for c in merged.columns if c not in exclude]

merged[cols_to_float] = merged[cols_to_float].astype(float)

# %%
def compare_metrics(row, pairs, tol=1e-15):
    styles = []
    for pl_col, qk_col in pairs:
        pl_val, qk_val = row[pl_col], row[qk_col]

        if abs(pl_val - qk_val) <= tol:
            styles += ["background-color: #ffffcc", "background-color: #ffffcc"]
        elif pl_val < qk_val:
            styles += ["background-color: green", ""]
        else:
            styles += ["", "background-color: green"]
    return styles

# %%
metric_pairs = [("Mean VQE time (s)_path1", "Mean VQE time (s)_path2"), ("Delta min E_path1","Delta min E_path2"), ("Delta median E_path1","Delta median E_path2"), ("Delta mean E_path1","Delta mean E_path2")]
merged.style.apply(lambda r: compare_metrics(r, metric_pairs),
                        subset=[c for pair in metric_pairs for c in pair],
                        axis=1)
# Out:
# <style type="text/css">
# #T_d3c8c_row0_col4, #T_d3c8c_row0_col5, #T_d3c8c_row0_col6, #T_d3c8c_row0_col9, #T_d3c8c_row0_col10, #T_d3c8c_row0_col11, #T_d3c8c_row4_col4, #T_d3c8c_row4_col5, #T_d3c8c_row4_col9, #T_d3c8c_row4_col10, #T_d3c8c_row8_col4, #T_d3c8c_row8_col5, #T_d3c8c_row8_col6, #T_d3c8c_row8_col9, #T_d3c8c_row8_col10, #T_d3c8c_row8_col11, #T_d3c8c_row9_col4, #T_d3c8c_row9_col5, #T_d3c8c_row9_col6, #T_d3c8c_row9_col9, #T_d3c8c_row9_col10, #T_d3c8c_row9_col11, #T_d3c8c_row10_col4, #T_d3c8c_row10_col5, #T_d3c8c_row10_col6, #T_d3c8c_row10_col9, #T_d3c8c_row10_col10, #T_d3c8c_row10_col11, #T_d3c8c_row11_col4, #T_d3c8c_row11_col5, #T_d3c8c_row11_col6, #T_d3c8c_row11_col9, #T_d3c8c_row11_col10, #T_d3c8c_row11_col11 {
#   background-color: #ffffcc;
# }
# #T_d3c8c_row0_col8, #T_d3c8c_row1_col3, #T_d3c8c_row1_col5, #T_d3c8c_row1_col6, #T_d3c8c_row1_col9, #T_d3c8c_row2_col3, #T_d3c8c_row2_col5, #T_d3c8c_row2_col6, #T_d3c8c_row2_col9, #T_d3c8c_row3_col3, #T_d3c8c_row3_col4, #T_d3c8c_row3_col6, #T_d3c8c_row3_col10, #T_d3c8c_row4_col8, #T_d3c8c_row4_col11, #T_d3c8c_row5_col3, #T_d3c8c_row5_col4, #T_d3c8c_row5_col10, #T_d3c8c_row5_col11, #T_d3c8c_row6_col4, #T_d3c8c_row6_col5, #T_d3c8c_row6_col6, #T_d3c8c_row6_col8, #T_d3c8c_row7_col4, #T_d3c8c_row7_col5, #T_d3c8c_row7_col8, #T_d3c8c_row7_col11, #T_d3c8c_row8_col8, #T_d3c8c_row9_col8, #T_d3c8c_row10_col8, #T_d3c8c_row11_col8 {
#   background-color: green;
# }
# </style>
# <table id="T_d3c8c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3c8c_level0_col0" class="col_heading level0 col0" >potential</th>
#       <th id="T_d3c8c_level0_col1" class="col_heading level0 col1" >cutoff</th>
#       <th id="T_d3c8c_level0_col2" class="col_heading level0 col2" >Converged Runs_path1</th>
#       <th id="T_d3c8c_level0_col3" class="col_heading level0 col3" >Mean VQE time (s)_path1</th>
#       <th id="T_d3c8c_level0_col4" class="col_heading level0 col4" >Delta min E_path1</th>
#       <th id="T_d3c8c_level0_col5" class="col_heading level0 col5" >Delta median E_path1</th>
#       <th id="T_d3c8c_level0_col6" class="col_heading level0 col6" >Delta mean E_path1</th>
#       <th id="T_d3c8c_level0_col7" class="col_heading level0 col7" >Converged Runs_path2</th>
#       <th id="T_d3c8c_level0_col8" class="col_heading level0 col8" >Mean VQE time (s)_path2</th>
#       <th id="T_d3c8c_level0_col9" class="col_heading level0 col9" >Delta min E_path2</th>
#       <th id="T_d3c8c_level0_col10" class="col_heading level0 col10" >Delta median E_path2</th>
#       <th id="T_d3c8c_level0_col11" class="col_heading level0 col11" >Delta mean E_path2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3c8c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3c8c_row0_col0" class="data row0 col0" >AHO</td>
#       <td id="T_d3c8c_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_d3c8c_row0_col2" class="data row0 col2" >100/100</td>
#       <td id="T_d3c8c_row0_col3" class="data row0 col3" >0.200000</td>
#       <td id="T_d3c8c_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_d3c8c_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_d3c8c_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_d3c8c_row0_col7" class="data row0 col7" >100/100</td>
#       <td id="T_d3c8c_row0_col8" class="data row0 col8" >0.160000</td>
#       <td id="T_d3c8c_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_d3c8c_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_d3c8c_row0_col11" class="data row0 col11" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d3c8c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d3c8c_row1_col0" class="data row1 col0" >AHO</td>
#       <td id="T_d3c8c_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_d3c8c_row1_col2" class="data row1 col2" >100/100</td>
#       <td id="T_d3c8c_row1_col3" class="data row1 col3" >0.370000</td>
#       <td id="T_d3c8c_row1_col4" class="data row1 col4" >0.182666</td>
#       <td id="T_d3c8c_row1_col5" class="data row1 col5" >0.049087</td>
#       <td id="T_d3c8c_row1_col6" class="data row1 col6" >0.455319</td>
#       <td id="T_d3c8c_row1_col7" class="data row1 col7" >100/100</td>
#       <td id="T_d3c8c_row1_col8" class="data row1 col8" >0.380000</td>
#       <td id="T_d3c8c_row1_col9" class="data row1 col9" >0.097893</td>
#       <td id="T_d3c8c_row1_col10" class="data row1 col10" >0.054010</td>
#       <td id="T_d3c8c_row1_col11" class="data row1 col11" >0.496775</td>
#     </tr>
#     <tr>
#       <th id="T_d3c8c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d3c8c_row2_col0" class="data row2 col0" >AHO</td>
#       <td id="T_d3c8c_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_d3c8c_row2_col2" class="data row2 col2" >100/100</td>
#       <td id="T_d3c8c_row2_col3" class="data row2 col3" >2.580000</td>
#       <td id="T_d3c8c_row2_col4" class="data row2 col4" >3.285090</td>
#       <td id="T_d3c8c_row2_col5" class="data row2 col5" >0.166817</td>
#       <td id="T_d3c8c_row2_col6" class="data row2 col6" >0.043025</td>
#       <td id="T_d3c8c_row2_col7" class="data row2 col7" >100/100</td>
#       <td id="T_d3c8c_row2_col8" class="data row2 col8" >3.520000</td>
#       <td id="T_d3c8c_row2_col9" class="data row2 col9" >3.010820</td>
#       <td id="T_d3c8c_row2_col10" class="data row2 col10" >0.838033</td>
#       <td id="T_d3c8c_row2_col11" class="data row2 col11" >1.117920</td>
#     </tr>
#     <tr>
#       <th id="T_d3c8c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d3c8c_row3_col0" class="data row3 col0" >AHO</td>
#       <td id="T_d3c8c_row3_col1" class="data row3 col1" >16</td>
#       <td id="T_d3c8c_row3_col2" class="data row3 col2" >100/100</td>
#       <td id="T_d3c8c_row3_col3" class="data row3 col3" >11.870000</td>
#       <td id="T_d3c8c_row3_col4" class="data row3 col4" >37.794600</td>
#       <td id="T_d3c8c_row3_col5" class="data row3 col5" >2.692690</td>
#       <td id="T_d3c8c_row3_col6" class="data row3 col6" >0.015511</td>
#       <td id="T_d3c8c_row3_col7" class="data row3 col7" >100/100</td>
#       <td id="T_d3c8c_row3_col8" class="data row3 col8" >12.020000</td>
#       <td id="T_d3c8c_row3_col9" class="data row3 col9" >37.840900</td>
#       <td id="T_d3c8c_row3_col10" class="data row3 col10" >1.180030</td>
#       <td id="T_d3c8c_row3_col11" class="data row3 col11" >2.174140</td>
#     </tr>
#     <tr>
#       <th id="T_d3c8c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d3c8c_row4_col0" class="data row4 col0" >DW</td>
#       <td id="T_d3c8c_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_d3c8c_row4_col2" class="data row4 col2" >100/100</td>
#       <td id="T_d3c8c_row4_col3" class="data row4 col3" >0.240000</td>
#       <td id="T_d3c8c_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_d3c8c_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_d3c8c_row4_col6" class="data row4 col6" >0.458891</td>
#       <td id="T_d3c8c_row4_col7" class="data row4 col7" >100/100</td>
#       <td id="T_d3c8c_row4_col8" class="data row4 col8" >0.180000</td>
#       <td id="T_d3c8c_row4_col9" class="data row4 col9" >0.000000</td>
#       <td id="T_d3c8c_row4_col10" class="data row4 col10" >0.000000</td>
#       <td id="T_d3c8c_row4_col11" class="data row4 col11" >0.405543</td>
#     </tr>
#     <tr>
#       <th id="T_d3c8c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d3c8c_row5_col0" class="data row5 col0" >DW</td>
#       <td id="T_d3c8c_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_d3c8c_row5_col2" class="data row5 col2" >100/100</td>
#       <td id="T_d3c8c_row5_col3" class="data row5 col3" >1.900000</td>
#       <td id="T_d3c8c_row5_col4" class="data row5 col4" >0.060165</td>
#       <td id="T_d3c8c_row5_col5" class="data row5 col5" >0.145912</td>
#       <td id="T_d3c8c_row5_col6" class="data row5 col6" >0.355271</td>
#       <td id="T_d3c8c_row5_col7" class="data row5 col7" >100/100</td>
#       <td id="T_d3c8c_row5_col8" cla

# %%
import pandas as pd
import json
import os

# %%
folder_path = r"C:\Users\Johnk\Documents\PhD\Quantum Computing Code\Quantum-Computing\SUSY\SUSY QM\PennyLane\VQE\Differential Evolution\Noise"
cutoffs = [2, 4, 8, 16, 32, 64, 128, 256]
folders = [f for f in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, f))]

# %%
parallel_time = []
total_time = []
device_time = []
cutoffss = []
potential = []
percentages = []

for f in folders:

    for cutoff in cutoffs:

        data_path = folder_path + "\\{}\\{}_{}.json".format(f,f, cutoff)
        
        with open(data_path, 'r') as file:
            data = json.load(file)

        potential.append(f)
        cutoffss.append(cutoff)
        parallel_time.append(data['parallel_run_time'])
        total_time.append(data['total_VQE_time'])
        device_time.append(data['total_device_time'])
        dev_perc = (pd.Timedelta(data['total_device_time']).total_seconds() / pd.Timedelta(data['total_VQE_time']).total_seconds()) * 100
        percentages.append(dev_perc)

# %%
df = {'potential': potential,
        'cutoff': cutoffss,
        'parallel_time': parallel_time,
        'total_time': total_time,
        'device_time': device_time,
        'device / total %': percentages}

# %%
pd.DataFrame(df)
# Out:
#    potential  cutoff   parallel_time               total_time     device_time  \
# 0        AHO       2  0:00:20.682285           0:10:16.968768  0:00:19.444167
# 1        AHO       4  0:00:12.546418           0:06:00.354135  0:00:11.339130
# 2        AHO       8  0:00:19.155892           0:09:47.500391  0:00:17.377715
# 3        AHO      16  0:02:11.105607           0:46:02.058423  0:01:18.062679
# 4        AHO      32  0:01:20.765366           0:42:21.767190  0:01:02.076913
# 5        AHO      64  0:03:11.592004           1:19:02.852391  0:01:16.349043
# 6        AHO     128  0:08:27.401224           3:58:43.837566  0:01:28.958301
# 7        AHO     256  0:37:30.189291          19:21:39.424037  0:01:45.293553
# 8         DW       2  0:00:13.963019           0:07:03.767080  0:00:11.940206
# 9         DW       4  0:00:37.152873           0:18:30.289249  0:00:26.021284
# 10        DW       8  0:23:39.685885           8:51:03.740514  0:11:43.841818
# 11        DW      16  0:20:53.428082           5:34:33.713743  0:06:59.071012
# 12        DW      32  0:23:34.515138           6:20:34.413965  0:07:02.302960
# 13        DW      64  0:34:02.353875           8:49:29.438932  0:07:17.070339
# 14        DW     128  1:20:34.962831    1 day, 6:21:44.398863  0:11:01.636530
# 15        DW     256  6:25:08.861289  5 days, 13:39:21.899324  0:12:30.718276
# 16       QHO       2  0:00:02.666108           0:01:16.626852  0:00:03.044886
# 17       QHO       4  0:00:02.911961           0:01:26.242331  0:00:03.294826
# 18       QHO       8  0:00:02.996287           0:01:31.582676  0:00:03.326841
# 19       QHO      16  0:00:03.068908           0:01:34.645484  0:00:03.206088
# 20       QHO      32  0:00:04.250352           0:02:07.786334  0:00:03.582344
# 21       QHO      64  0:00:07.507818           0:03:56.972294  0:00:04.224683
# 22       QHO     128  0:00:25.894778           0:13:01.628665  0:00:04.946965
# 23       QHO     256  0:01:53.926504           1:01:23.177351  0:00:05.691883
#
#     device / total %
# 0           3.151564
# 1           3.146663
# 2           2.957907
# 3           2.826250
# 4           2.442274
# 5           1.609771
# 6           0.621051
# 7           0.151068
# 8           2.817634
# 9           2.343649
# 10          2.208911
# 11          2.087661
# 12          1.849414
# 13          1.375757
# 14          0.605316
# 15          0.156022
# 16          3.973654
# 17          3.820428
# 18          3.632610
# 19          3.387471
# 20          2.803386
# 21          1.782775
# 22          0.632905
# 23          0.154537

# %%
import pandas as pd
import numpy as np
import json
import os

# %%
folder_path = r"C:\Users\Johnk\OneDrive\Desktop\PhD 2024\Quantum Computing Code\Quantum-Computing\SUSY\SUSY QM\PennyLane\VQD\Differential Evolution\Files"
cutoff = 16
folders = [f for f in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, f))]

# %%
folders
# Out:
# ['AHO', 'DW', 'QHO']

# %%
all_data = []
potentials = []
e0 = []
e1 = []
e2 = []
ratios = []

for f in folders:
    
    data_path = folder_path + "\\{}\\{}_{}.json".format(f,f, cutoff)
    
    with open(data_path, 'r') as file:
        data = json.load(file)

    energies = np.sort(data['results'])

    for e in energies:
        potentials.append(f)
        e0.append(e[0])
        e1.append(e[1])
        e2.append(e[2])

        r = abs((e[2] - e[1]) / (e[2] - e[0]))
        ratios.append(r)

df = {
"potential": potentials,
    "cutoff": cutoff,
    "e0": e0,
    "e1": e1,
    "e2": e2,
    "ratios": ratios
    }

# %%
df = pd.DataFrame(df)
df
# Out:
#     potential  cutoff        e0        e1        e2    ratios
# 0         AHO      16 -0.001167  1.664298  1.968770  0.154559
# 1         AHO      16 -0.001167  1.674728  1.959051  0.145046
# 2         AHO      16 -0.001167  1.714596  2.011680  0.147594
# 3         AHO      16 -0.001167  1.694502  1.991904  0.149218
# 4         AHO      16 -0.001167  1.697508  2.001521  0.151803
# ..        ...     ...       ...       ...       ...       ...
# 115       QHO      16  0.000000  0.959961  0.986133  0.026540
# 116       QHO      16  0.000000  0.962305  0.983594  0.021644
# 117       QHO      16  0.000000  0.971484  0.985937  0.014659
# 118       QHO      16  0.000000  0.965234  0.985937  0.020998
# 119       QHO      16  0.000000  0.967383  0.971289  0.004022
#
# [120 rows x 6 columns]

# %%
median = []
mean = []
min = []
potentials = []

for f in folders:

    potentials.append(f)
    data = df[df['potential'] == f]
    median.append(np.median(data['ratios']))
    mean.append(np.mean(data['ratios']))
    min.append(np.min(data['ratios']))

aggdf = {
    "potential": potentials,
    "cutoff": cutoff,
    "median": median,
    "mean": mean,
    "min": min,
}

# %%
pd.DataFrame(aggdf)
# Out:
#   potential  cutoff    median      mean       min
# 0       AHO      16  0.136283  0.130538  0.006673
# 1        DW      16  0.987604  0.986971  0.965012
# 2       QHO      16  0.020959  0.019326  0.002788

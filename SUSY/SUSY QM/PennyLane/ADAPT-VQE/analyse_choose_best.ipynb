# %%
import os
import json

import numpy as np
import pandas as pd
import pennylane as qml

# %%
folder_path = r"C:\Users\Johnk\Documents\PhD\Quantum Computing Code\Quantum-Computing\SUSY\SUSY QM\PennyLane\ADAPT-VQE\COBYLA-Test\StatevectorFiles-Overlap\DW"
file_paths = os.listdir(folder_path)

# %%
json_files = [f for f in file_paths if f.endswith('.json')]
json_files
# Out:
# ['DW_16.json', 'DW_2.json', 'DW_32.json', 'DW_4.json', 'DW_8.json']

# %%
for file in json_files:
    
    data_path = os.path.join(folder_path,file)
    data_dict = {}

    with open(data_path, 'r') as file:
            data = json.load(file)

    cutoff = data['cutoff']
    potential = data['potential']
    energies = data['all_energies']

    print("########################################################################")
    print(f"Finding optimal circuit for {potential} - cutoff {cutoff}")

    num_qubits = int(np.log2(cutoff)) + 1
    min_eigenvalue = min(data['exact_eigenvalues'])

    closest_e = np.inf
    best_index = 0
    gate_length = np.inf
    best_energy_value = None
    best_gate_position = None

    for i, e1 in enumerate(energies):
        for g_idx, e2 in enumerate(e1, start=1):  # gate count = index
            ediff = abs(e2 - min_eigenvalue)

            # if closer OR equal but with fewer gates
            if ediff < closest_e or ((np.abs(ediff - closest_e) < 1e-3) and g_idx < gate_length):
            #if ediff < closest_e or (ediff == closest_e and g_idx < gate_length):
                closest_e = ediff
                best_index = i
                gate_length = g_idx
                best_energy_value = e2
                best_gate_position = g_idx

    best_gate_set = data['op_list'][best_index]
    best_energy_list = energies[best_index]

    print(f"Exact eigenvalue: {min_eigenvalue}")
    print(f"Closest energy: {best_energy_value}")
    print(f"Energy list for best circuit: {best_energy_list}")
    print(f"Gates needed to reach best energy: {best_gate_position}")
    print(f"Gate sequence: {best_gate_set}")


    basis_state = data["basis_state"]
    best_circuit = best_gate_set[:best_gate_position]

    data_dict = {}
    data_dict['potential'] = potential
    data_dict['cutoff'] = cutoff
    data_dict['basis_state'] = basis_state
    data_dict['min_eigenvalue'] = min_eigenvalue
    data_dict['best_energy_value'] = best_energy_value
    data_dict['circuit'] = best_circuit

    file_path = os.path.join(folder_path, f"data_{cutoff}.txt")

    with open(file_path, "w") as file:
        json.dump(data_dict, file, indent=4)

    # Define the device
    dev = qml.device("default.qubit", wires=num_qubits)


    @qml.qnode(dev)
    def circuit():

        qml.BasisState(basis_state, wires=range(num_qubits))

        for op_dict in best_circuit:
            op = getattr(qml, op_dict["name"])
            op(op_dict['param'], wires=op_dict['wires'])

        return qml.state()

    circuit_diagram = qml.draw(circuit)()
    mpl_diagram, ax = qml.draw_mpl(circuit, style='pennylane')()

    diagram_path = os.path.join(folder_path, "circuitDiagrams")
    os.makedirs(diagram_path, exist_ok=True)
    mpl_diagram.savefig(diagram_path + f"\\{potential}_{cutoff}.png")


    with open(file_path, "a", encoding="utf-8") as file:
        file.write("\n###############################\n")
        file.write(circuit_diagram)
        file.write("\n###############################\n")
# Out:
# ########################################################################
# Finding optimal circuit for DW - cutoff 16
# Exact eigenvalue: 0.8915993623272772
# Closest energy: 0.8917906908972176
# Energy list for best circuit: [1.0939110867544655, 0.9871553299834243, 0.9748052943904236, 0.9188320711761827, 0.916445109464108, 0.906359265502158, 0.9059970222622584, 0.9041306324839244, 0.896480317829954, 0.8938307629978208, 0.8929417577953521, 0.8928480607729193, 0.8927473752686074, 0.8920789131531558, 0.8920352955237606, 0.8917906908972176, 0.8963354078329832, 0.8934484572909868, 0.8935646453735354, 0.8929280219146242, 0.8929659858597732, 0.8929077955458377, 0.8979087551197448, 0.892170615709294, 0.8924374275621066, 0.8926168355710818, 0.8926243262277235, 0.893031324660049, 0.8932901516879044, 0.8939548098643267]
# Gates needed to reach best energy: 16
# Gate sequence: [{'name': 'RY', 'param': -1.1792218358547204, 'wires': [4]}, {'name': 'CRY', 'param': -0.07843172575900853, 'wires': [4, 3]}, {'name': 'RY', 'param': -0.8303245117458444, 'wires': [2]}, {'name': 'RY', 'param': -1.1059315823918003, 'wires': [3]}, {'name': 'RY', 'param': -0.0856806413356368, 'wires': [1]}, {'name': 'CRY', 'param': -0.3749905048196624, 'wires': [4, 2]}, {'name': 'CRY', 'param': -0.010527320538268952, 'wires': [4, 1]}, {'name': 'CRY', 'param': 0.06250697707588598, 'wires': [3, 2]}, {'name': 'RY', 'param': 2.129704564066443, 'wires': [3]}, {'name': 'CRY', 'param': -0.007355688233377395, 'wires': [3, 1]}, {'name': 'CRY', 'param': 0.04574269158763244, 'wires': [2, 1]}, {'name': 'RY', 'param': -0.35922285459900505, 'wires': [3]}, {'name': 'RY', 'param': -0.5858158245752577, 'wires': [4]}, {'name': 'RY', 'param': 0.08575916677403424, 'wires': [1]}, {'name': 'RY', 'param': 0.9017238525152154, 'wires': [2]}, {'name': 'CRY', 'param': 2.6786501332306636, 'wires': [1, 2]}, {'name': 'RY', 'param': 0.005910823967739794, 'wires': [1]}, {'name': 'CRY', 'param': 2.1467416162518256, 'wires': [2, 4]}, {'name': 'RY', 'param': 0.2704708652787306, 'wires': [2]}, {'name': 'CRY', 'param': 5.102659430288747, 'wires': [3, 4]}, {'name': 'CRY', 'param': 5.0399347498026765, 'wires': [2, 3]}, {'name': 'CRY', 'param': 0.29182112677531197, 'wires': [1, 4]}, {'name': 'RY', 'param': -0.033142553266990546, 'wires': [1]}, {'name': 'RY', 'param': -0.06669096680483678, 'wires': [2]}, {'name': 'RY', 'param': 0.3128368467997416, 'wires': [3]}, {'name': 'CRY', 'param': 2.272840031069519, 'wires': [1, 3]}, {'name': 'RY', 'param': 0.005071359257728619, 'wires': [1]}, {'name': 'RY', 'param': 0.3900478740046674, 'wires': [3]}, {'name': 'RY', 'param': 0.6216391091203438, 'wires': [4]}, {'name': 'RY', 'param': 0.06711205625785699, 'wires': [0]}]
# ########################################################################
# Finding optimal circuit for DW - cutoff 2
# Exact eigenvalue: 0.35723304703363135
# Closest energy: 0.35723304703363135
# Energy list for best circuit: [0.35723304703363135]
# Gates needed to reach best energy: 1
# Gate sequence: [{'name': 'RY', 'param': 4.712388980866209, 'wires': [1]}]
# ########################################################################
# Finding optimal circuit for DW - cutoff 32
# Exact eigenvalue: 0.8916323705551651
# Closest energy: 0.8921639375529199
# Energy list for best circuit: [1.0939110867544652, 0.9871553299834243, 0.9748052943904227, 0.918832071176184, 0.9164449861095803, 0.9063594017263092, 0.9059972506329307, 0.9041308651722771, 0.892835063902874, 0.8927361748455833, 0.8939683136030147, 0.8990911698174535, 0.9135842233759266, 0.8929128108409261, 0.9171637017037465, 0.8922657020181993, 0.9314329172783763, 0.8921639375529199, 0.8937417639786834, 0.9011554395075567]
# Gates needed to reach best energy: 18
# Gate sequence: [{'name': 'RY', 'param': 5.6690481830900605, 'wires': [5]}, {'name': 'CRY', 'param': 5.300837889532512, 'wires': [5, 4]}, {'name': 'RY', 'param': 8.558771249278223, 'wires': [3]}, {'name': 'RY', 'param': 8.701221508888345, 'wires': [4]}, {'name': 'RY', 'param': 8.03428227642701, 'wires': [2]}, {'name': 'CRY', 'param': 6.45427265706172, 'wires': [5, 3]}, {'name': 'CRY', 'param': 6.263909723974857, 'wires': [5, 2]}, {'name': 'CRY', 'param': 6.340751929064716, 'wires': [4, 3]}, {'name': 'RY', 'param': 2.099036097498316, 'wires': [4]}, {'name': 'CRY', 'param': 6.274154791432422, 'wires': [4, 2]}, {'name': 'CRY', 'param': 6.2738128521451895, 'wires': [5, 1]}, {'name': 'RY', 'param': 6.2787385093540715, 'wires': [1]}, {'name': 'CRY', 'param': 6.168097682483436, 'wires': [3, 4]}, {'name': 'RY', 'param': 5.265571486222914, 'wires': [3]}, {'name': 'CRY', 'param': 5.601027501742873, 'wires': [3, 5]}, {'name': 'RY', 'param': 6.508631342685171, 'wires': [3]}, {'name': 'CRY', 'param': 7.507788678524461, 'wires': [3, 2]}, {'name': 'RY', 'param': 5.095196704162279, 'wires': [3]}, {'name': 'CRY', 'param': 4.518807249784737, 'wires': [2, 3]}, {'name': 'RY', 'param': 2.8341970235546734, 'wires': [2]}]
# ########################################################################
# Finding optimal circuit for DW - cutoff 4
# Exact eigenvalue: 0.9065598714743818
# Closest energy: 0.9065598714743881
# Energy list for best circuit: [0.9539032146604696, 0.9080978611536562, 0.9065598714743881]
# Gates needed to reach best energy: 3
# Gate sequence: [{'name': 'RY', 'param': -0.396650822461348, 'wires': [1]}, {'name': 'RY', 'param': -0.3312683635630427, 'wires': [2]}, {'name': 'CRY', 'param': -0.27471716481596453, 'wires': [1, 2]}]
# ########################################################################
# Finding optimal circuit for DW - cutoff 8
# Exact eigenvalue: 0.8845804438664027
# Closest energy: 0.8845804439896114
# Energy list for best circuit: [1.0939110867544652, 0.9871553299834241, 0.9750917310621461, 0.9190887936371128, 0.9092928098842114, 0.9043758920546433, 0.8849186068203976, 0.8845804439896114]
# Gates needed to reach best energy: 8
# Gate sequence: [{'name': 'RY', 'param': -1.2664663576198527, 'wires': [3]}, {'name': 'CRY', 'param': -0.6510582175670251, 'wires': [3, 2]}, {'name': 'RY', 'param': -0.4151889157842444, 'wires': [1]}, {'name': 'RY', 'param': 2.043645924778922, 'wires': [2]}, {'name': 'CRY', 'param': 0.188033238074714, 'wires': [3, 1]}, {'name': 'CRY', 'param': 0.26903857257656466, 'wires': [2, 1]}, {'name': 'RY', 'param': -1.716887078991932, 'wires': [2]}, {'name': 'CRY', 'param': -0.05640035161101607, 'wires': [2, 3]}]
